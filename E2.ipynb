# %% [markdown]
# # E2 Assessment

# %% [markdown]
# # Part 1 - Flat data and headers

# %%
import pandas as pd

# specify your file path
file_path = "for_nitpicker.dat"

# load the file (tab-separated)
df = pd.read_csv(file_path, sep="\t", header=None)

# %%
df.columns = ["date", "time", "depth", "temperature(°C)", "salinity(psu)"]  # replace with your desired names
